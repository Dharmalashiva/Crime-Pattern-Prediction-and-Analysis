# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharmalashiva/Crime-Pattern-Prediction-and-Analysis/blob/main/Prediction4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Crime Trend Predictions Using ARIMA and VAR Models
    ------------------------------------------------
Overview
In this analysis, we employ ARIMA and VAR models to forecast crime trends across India.
ARIMA focuses on predicting future crime rates based on historical data for individual states or districts,
while VAR captures the interdependencies among different crime categories, offering both state-level and national insights.
Together, these models provide a robust framework for understanding and projecting crime trends, aiding in data-driven decision-making for policy and planning.

Predicting Future Crimes Using ARIMA (2014-2023)
------------------------------------------------
Overview
In this section, we employ the ARIMA (AutoRegressive Integrated Moving Average) model to forecast crime trends for the years 2014 to 2023. ARIMA is a robust statistical method designed for time series forecasting, effectively capturing trends and seasonality in data.

ARIMA Components
----------------
AutoRegression (AR): Models the relationship between an observation and its lagged values.
Integrated (I): Applies differencing to make the time series stationary.
Moving Average (MA): Models the relationship between an observation and the residual errors from a lagged moving average.
'''

'''
Preprocessing: Stationarity Check and Differencing
To ensure accurate forecasts, we performed the following preprocessing steps:

1.Stationarity Check:
Conducted the Augmented Dickey-Fuller (ADF) test to assess stationarity.
Observed that raw crime data exhibited non-stationary behavior, with trends and seasonality affecting the series.

2.Differencing:
Applied differencing techniques to stabilize the mean and remove trends, transforming the data into a stationary time series suitable for ARIMA modeling.
Ensured that the differenced series passed the stationarity test with consistent mean and variance.'''

import pandas as pd
from sklearn.preprocessing import LabelEncoder

data = pd.read_csv('crimes_cleaned.csv')

# Create backup columns to store the original 'STATE/UT' and 'DISTRICT' values
data['STATE/UT_original'] = data['STATE/UT']
data['DISTRICT_original'] = data['DISTRICT']



# Initialize the label encoder to convert categorical data into numeric labels
label_encoder = LabelEncoder()

# Encode 'STATE/UT' and 'DISTRICT' columns with numeric labels
data['STATE/UT'] = label_encoder.fit_transform(data['STATE/UT'])
data['DISTRICT'] = label_encoder.fit_transform(data['DISTRICT'])

# Configure pandas to display all rows (avoids truncation of output)
pd.set_option('display.max_rows', None)

# Print the comparison of original and encoded values for 'STATE/UT' and 'DISTRICT'
print("Original vs. Encoded Values for STATE/UT and DISTRICT:")
print(data[['STATE/UT_original', 'STATE/UT', 'DISTRICT_original', 'DISTRICT']])

# Reset the display options to default (useful after the operation)
pd.reset_option('display.max_rows')
# Out:
# Original vs. Encoded Values for STATE/UT and DISTRICT:
#       STATE/UT_original  STATE/UT     DISTRICT_original  DISTRICT
# 0        ANDHRA PRADESH         2              ADILABAD         3
# 1        ANDHRA PRADESH         2             ANANTAPUR        31
# 2        ANDHRA PRADESH         2              CHITTOOR       157
# 3        ANDHRA PRADESH         2              CUDDAPAH       175
# 4        ANDHRA PRADESH         2             CYBERABAD       177
# 5        ANDHRA PRADESH         2         EAST GODAVARI       225
# 6        ANDHRA PRADESH         2         GUNTAKAL RLY.       284
# 7        ANDHRA PRADESH         2                GUNTUR       285
# 8        ANDHRA PRADESH         2          GUNTUR URBAN       286
# 9        ANDHRA PRADESH         2        HYDERABAD CITY       313
# 10       ANDHRA PRADESH         2            KARIMNAGAR       398
# 65                ASSAM         4         GUWAHATI CITY       289
# 66                ASSAM         4            HAILAKANDI       291
# 67                ASSAM         4                HAMREN       293
# 68                ASSAM         4                JORHAT       372
# 69                ASSAM         4                KAMRUP       381
# 70                ASSAM         4         KARBI ANGLONG       395
# 71                ASSAM         4             KARIMGANJ       397
# 72                ASSAM         4             KOKRAJHAR       432
# 73                ASSAM         4             LAKHIMPUR       464
# 74                ASSAM         4              MORIGAON       516
# 75                ASSAM         4             N.C.HILLS       530
# 76                ASSAM         4                NAGAON       532
# 77                ASSAM         4               NALBARI       540
# 78                ASSAM         4                R.P.O.       614
# 79                ASSAM         4              SIBSAGAR       697
# 80                ASSAM         4              SONITPUR       721
# 81                ASSAM         4                   STF       735
# 82                ASSAM         4              TINSUKIA       766
# 83                ASSAM         4              UDALGURI       781
# 84                BIHAR         5                ARARIA        37
# 85                BIHAR         5                 ARWAL        39
# 86                BIHAR         5            AURANGABAD        43
# 87                BIHAR         5                BAGAHA        50
# 88                BIHAR         5                 BANKA        66
# 89                BIHAR         5             BEGUSARAI        83
# 90                BIHAR         5               BETTIAH        88
# 91                BIHAR         5               BHABHUA        90
# 92                BIHAR         5             BHAGALPUR        92
# 93                BIHAR         5               BHOJPUR       102
# 94                BIHAR         5                 BUXAR       127
# 95                BIHAR         5             DARBHANGA       186
# 96                BIHAR         5                  GAYA       266
# 97                BIHAR         5             GOPALGANJ       276
# 98                BIHAR         5         JAMALPUR RLY.       348
# 99                BIHAR         5                 JAMUI       354
# 100               BIHAR         5             JEHANABAD       358
# 101               BIHAR         5               KATIHAR       404
# 102               BIHAR         5          KATIHAR RLY.       405
# 103               BIHAR         5              KHAGARIA       411
# 104               BIHAR         5            KISHANGANJ       427
# 105               BIHAR         5            LAKHISARAI       465
# 106               BIHAR         5             MADHEPURA       480
# 107               BIHAR         5             MADHUBANI       481
# 108               BIHAR         5              MOTIHARI       517
# 109               BIHAR         5                MUNGER       523
# 110               BIHAR         5           MUZAFFARPUR       526
# 111               BIHAR         5      MUZAFFARPUR RLY.       527
# 112               BIHAR         5               NALANDA       539
# 113               BIHAR         5             NAUGACHIA       550
# 114               BIHAR         5               NAWADAH       553
# 115               BIHAR         5                 PATNA       590
# 116               BIHAR         5            PATNA RLY.       591
# 117               BIHAR         5                PURNEA       612
# 118               BIHAR         5                ROHTAS       649
# 119               BIHAR         5               SAHARSA       657
# 120               BIHAR         5            SAMASTIPUR       662
# 121               BIHAR         5                 SARAN       670
# 122               BIHAR         5            SHEIKHPURA       686
# 123               BIHAR         5               SHEOHAR       687
# 124               BIHAR         5             SITAMARHI       711
# 125               BIHAR         5                 SIWAN       714
# 126               BIHAR         5                SUPAUL       741
# 127               BIHAR         5              VAISHALI       797
# 128        CHHATTISGARH         7                 BALOD        59
# 129        CHHATTISGARH         7          BALODA BAZAR        60
# 130        CHHATTISGARH         7             BALRAMPUR        61
# 131        CHHATTISGARH         7              BEMETARA        86
# 132        CHHATTISGARH         7              BILASPUR       110
# 133        CHHATTISGARH         7               BIZAPUR       113
# 134        CHHATTISGARH         7             DANTEWARA       185
# 135        CHHATTISGARH         7              DHAMTARI       201
# 136        CHHATTISGARH         7                  DURG       223
# 137        CHHATTISGARH         7            GARIYABAND       259
# 138        CHHATTISGARH         7            GRP RAIPUR       279
# 139        CHHATTISGARH         7             JAGDALPUR       328
# 140        CHHATTISGARH         7               JANJGIR       355
# 141        CHHATTISGARH         7               JASHPUR       356
# 142        CHHATTISGARH         7             KABIRDHAM       376
# 143        CHHATTISGARH         7                KANKER       385
# 144        CHHATTISGARH         7             KONDAGAON       440
# 145        CHHATTISGARH         7                 KORBA       443
# 146        CHHATTISGARH         7                KORIYA       444
# 147        CHHATTISGARH         7            MAHASAMUND       486
# 148        CHHATTISGARH         7               MUNGELI       522
# 149        CHHATTISGARH         7            NARAYANPUR       545
# 150        CHHATTISGARH         7               RAIGARH       618
# 151        CHHATTISGARH         7                RAIPUR       624
# 152        CHHATTISGARH         7           RAJNANDGAON       630
# 153        CHHATTISGARH         7               SARGUJA       671
# 154        CHHATTISGARH         7                 SUKMA       738
# 155        CHHATTISGARH         7              SURAJPUR       742
# 156                 GOA        12             NORTH GOA       564
# 157                 GOA        12             SOUTH GOA       724
# 158             GUJARAT        13      AHMEDABAD COMMR.         6
# 159             GUJARAT        13       AHMEDABAD RURAL         7
# 160             GUJARAT        13             AHWA-DANG         9
# 161             GUJARAT        13                AMRELI        26
# 162             GUJARAT        13                 ANAND        30
# 163             GUJARAT        13               BHARUCH        95
# 164             GUJARAT        13             BHAVNAGAR        97
# 165             GUJARAT        13             CID CRIME       162
# 166             GUJARAT        13                 DAHOD       180
# 167             GUJARAT        13           GANDHINAGAR       255
# 168             GUJARAT        13            HIMATNAGAR       304
# 169             GUJARAT        13              JAMNAGAR       350
# 170             GUJARAT        13              JUNAGADH       373
# 171             GUJARAT        13           KHEDA NORTH       420
# 172             GUJARAT        13       KUTCH (EAST(G))       461
# 173             GUJARAT        13     KUTCH (WEST-BHUJ)       462
# 174             GUJARAT        13               MEHSANA       506
# 175             GUJARAT        13               NARMADA       546
# 176             GUJARAT        13               NAVSARI       552
# 177             GUJARAT        13              PALANPUR       575
# 178             GUJARAT        13            PANCHMAHAL       579
# 179             GUJARAT        13                 PATAN       586
# 180             GUJARAT        13             PORBANDAR       600
# 181             GUJARAT        13         RAJKOT COMMR.       628
# 182             GUJARAT        13          RAJKOT RURAL       629
# 183             GUJARAT        13          SURAT COMMR.       743
# 184             GUJARAT        13           SURAT RURAL       744
# 185             GUJARAT        13         SURENDRANAGAR       745
# 186             GUJARAT        13                  TAPI       747
# 187             GUJARAT        13       VADODARA COMMR.       795
# 188             GUJARAT        13        VADODARA RURAL       796
# 189             GUJARAT        13                VALSAD       798
# 190             GUJARAT        13       W.RLY AHMEDABAD       812
# 191             GUJARAT        13        W.RLY VADODARA       813
# 192             HARYANA        14          AMBALA RURAL        20
# 193             HARYANA        14          AMBALA URBAN        21
# 194             HARYANA        14               BHIWANI       101
# 195             HARYANA        14             FARIDABAD       234
# 196             HARYANA        14             FATEHABAD       236
# 197             HARYANA        14                   GRP       278
# 198             HARYANA        14               GURGAON       288
# 199             HARYANA        14                HISSAR       306
# 200             HARYANA        14           I&P HARYANA       314
# 201             HARYANA        14               JHAJJAR       360
# 202             HARYANA        14                  JIND       366
# 203             HARYANA        14               KAITHAL       377
# 204             HARYANA        14                KARNAL       399
# 205             HARYANA        14           KURUKSHETRA       458
# 206             HARYANA        14          MAHENDRAGARH       487
# 207             HARYANA        14                 MEWAT       508
# 208             HARYANA        14                PALWAL       577
# 209             HARYANA        14             PANCHKULA       578
# 210             HARYANA        14               PANIPAT       581
# 211             HARYANA        14                REWARI       646
# 212             HARYANA        14                ROHTAK       648
# 213             HARYANA        14                 SIRSA       710
# 214             HARYANA        14               SONIPAT       720
# 215             HARYANA        14           YAMUNANAGAR       823
# 216    HIMACHAL PRADESH        15       BADDIPOLICEDIST        49
# 217    HIMACHAL PRADESH        15              BILASPUR       110
# 218    HIMACHAL PRADESH        15                CHAMBA       137
# 219    HIMACHAL PRADESH        15                   CID       161
# 220    HIMACHAL PRADESH        15                G.R.P.       245
# 221    HIMACHAL PRADESH        15              HAMIRPUR       292
# 222    HIMACHAL PRADESH        15                KANGRA       384
# 223    HIMACHAL PRADESH        15               KINNAUR       425
# 224    HIMACHAL PRADESH        15                 KULLU       455
# 225    HIMACHAL PRADESH        15          LAHAUL-SPITI       463
# 226    HIMACHAL PRADESH        15                 MANDI       495
# 227    HIMACHAL PRADESH        15                SHIMLA       689
# 228    HIMACHAL PRADESH        15               SIRMAUR       708
# 229    HIMACHAL PRADESH        15                 SOLAN       715
# 230    HIMACHAL PRADESH        15                   UNA       788
# 231     JAMMU & KASHMIR        16              ANANTNAG        32
# 232     JAMMU & KASHMIR        16            AWANTIPORA        46
# 233     JAMMU & KASHMIR        16             BANDIPORA        63
# 234     JAMMU & KASHMIR        16             BARAMULLA        71
# 235     JAMMU & KASHMIR        16                BUDGAM       121
# 236     JAMMU & KASHMIR        16           CRIME JAMMU       170
# 237     JAMMU & KASHMIR        16        CRIME SRINAGAR       172
# 238     JAMMU & KASHMIR        16                  DODA       220
# 239     JAMMU & KASHMIR        16             GANDERBAL       254
# 240     JAMMU & KASHMIR        16              HANDWARA       294
# 241     JAMMU & KASHMIR        16                 JAMMU       349
# 242     JAMMU & KASHMIR        16                KARGIL       396
# 243     JAMMU & KASHMIR        16                KATHUA       403
# 244     JAMMU & KASHMIR        16              KISHTWAR       428
# 245     JAMMU & KASHMIR        16                KULGAM       454
# 246     JAMMU & KASHMIR        16               KUPWARA       456
# 247     JAMMU & KASHMIR        16                   LEH       471
# 248     JAMMU & KASHMIR        16                POONCH       599
# 249     JAMMU & KASHMIR        16               PULWAMA       606
# 250     JAMMU & KASHMIR        16        RAILWAYS JAMMU       620
# 251     JAMMU & KASHMIR        16      RAILWAYS KASHMIR       621
# 252     JAMMU & KASHMIR        16        RAILWAYS KATRA       622
# 253     JAMMU & KASHMIR        16               RAJOURI       631
# 254     JAMMU & KASHMIR        16                RAMBAN       635
# 255     JAMMU & KASHMIR        16                 REASI       644
# 256     JAMMU & KASHMIR        16                 SAMBA       663
# 257     JAMMU & KASHMIR        16               SHOPIAN       692
# 258     JAMMU & KASHMIR        16                SOPORE       722
# 259     JAMMU & KASHMIR        16              SRINAGAR       731
# 260     JAMMU & KASHMIR        16              UDHAMPUR       782
# 261           JHARKHAND        17                BOKARO       115
# 262           JHARKHAND        17              CHAIBASA       135
# 263           JHARKHAND        17                CHATRA       146
# 264           JHARKHAND        17               DEOGHAR       197
# 265           JHARKHAND        17               DHANBAD       202
# 266           JHARKHAND        17          DHANBAD RLY.       203
# 267           JHARKHAND        17                 DUMKA       221
# 268           JHARKHAND        17                GARHWA       258
# 269           JHARKHAND        17               GIRIDIH       269
# 270           JHARKHAND        17                 GODDA       271
# 271           JHARKHAND        17                 GUMLA       282
# 272           JHARKHAND        17            HAZARIBAGH       303
# 273           JHARKHAND        17            JAMSHEDPUR       351
# 274           JHARKHAND        17       JAMSHEDPUR RLY.       352
# 275           JHARKHAND        17               JAMTARA       353
# 276           JHARKHAND        17                KHUNTI       423
# 277           JHARKHAND        17               KODERMA       430
# 278           JHARKHAND        17               LATEHAR       468
# 279           JHARKHAND        17            LOHARDAGGA       472
# 280           JHARKHAND        17                 PAKUR       572
# 281           JHARKHAND        17                PALAMU       574
# 282           JHARKHAND        17               RAMGARH       636
# 283           JHARKHAND        17                RANCHI       639
# 284           JHARKHAND        17             SAHEBGANJ       658
# 285           JHARKHAND        17             SARAIKELA       669
# 286           JHARKHAND        17               SIMDEGA       704
# 287           KARNATAKA        18              BAGALKOT        51
# 288           KARNATAKA        18      BANGALORE COMMR.        64
# 289           KARNATAKA        18       BANGALORE RURAL        65
# 290           KARNATAKA        18               BELGAUM        84
# 291           KARNATAKA        18               BELLARY        85
# 292           KARNATAKA        18                 BIDAR       105
# 293           KARNATAKA        18               BIJAPUR       107
# 294           KARNATAKA        18                CBPURA       133
# 295           KARNATAKA        18         CHAMARAJNAGAR       136
# 296           KARNATAKA        18          CHICKMAGALUR       153
# 297           KARNATAKA        18           CHITRADURGA       155
# 298           KARNATAKA        18       DAKSHIN KANNADA       182
# 299           KARNATAKA        18            DAVANAGERE       191
# 300           KARNATAKA        18        DHARWAD COMMR.       206
# 301           KARNATAKA        18         DHARWAD RURAL       207
# 302           KARNATAKA        18                 GADAG       251
# 303           KARNATAKA        18              GULBARGA       281
# 304           KARNATAKA        18                HASSAN       300
# 305           KARNATAKA        18                HAVERI       302
# 306           KARNATAKA        18                K.G.F.       374
# 307           KARNATAKA        18                KODAGU       429
# 308           KARNATAKA        18                 KOLAR       433
# 309           KARNATAKA        18                KOPPAL       441
# 310           KARNATAKA        18                MANDYA       498
# 311           KARNATAKA        18        MANGALORE CITY       499
# 312           KARNATAKA        18         MYSORE COMMR.       528
# 313           KARNATAKA        18          MYSORE RURAL       529
# 314           KARNATAKA        18               RAICHUR       616
# 433         MAHARASHTRA        22            SINDHUDURG       705
# 434         MAHARASHTRA        22        SOLAPUR COMMR.       716
# 435         MAHARASHTRA        22         SOLAPUR RURAL       717
# 436         MAHARASHTRA        22          THANE COMMR.       751
# 437         MAHARASHTRA        22           THANE RURAL       752
# 438         MAHARASHTRA        22                WARDHA       816
# 439         MAHARASHTRA        22                WASHIM       817
# 440         MAHARASHTRA        22              YAVATMAL       824
# 441             MANIPUR        23             BISHNUPUR       112
# 442             MANIPUR        23               CHANDEL       141
# 443             MANIPUR        23         CHURACHANDPUR       159
# 444             MANIPUR        23                   CID       161
# 445             MANIPUR        23           IMPHAL EAST       318
# 446             MANIPUR        23           IMPHAL WEST       319
# 447             MANIPUR        23              SENAPATI       679
# 448             MANIPUR        23            TAMENGLONG       746
# 449             MANIPUR        23               THOUBAL       761
# 450             MANIPUR        23                UKHRUL       786
# 451           MEGHALAYA        24       GARO HILLS EAST       260
# 452           MEGHALAYA        24      GARO HILLS NORTH       261
# 453           MEGHALAYA        24      GARO HILLS SOUTH       262
# 454           MEGHALAYA        24   GARO HILLS SOUTH W.       263
# 455           MEGHALAYA        24       GARO HILLS WEST       264
# 456           MEGHALAYA        24    JAINTIA HILLS EAST       331
# 457           MEGHALAYA        24    JAINTIA HILLS WEST       332
# 458           MEGHALAYA        24      KHASI HILLS EAST       417
# 459           MEGHALAYA        24  KHASI HILLS SOUTH W.       418
# 460           MEGHALAYA        24      KHASI HILLS WEST       419
# 461           MEGHALAYA        24               RI-BHOI       647
# 462             MIZORAM        25                AIZAWL        10
# 463             MIZORAM        25              CHAMPHAI       140
# 464             MIZORAM        25               KOLASIB       434
# 465             MIZORAM        25             LAWNGTLAI       470
# 466             MIZORAM        25               LUNGLEI       479
# 467             MIZORAM        25                 MAMIT       494
# 468             MIZORAM        25                 SAIHA       659
# 469             MIZORAM        25              SERCHHIP       681
# 470             MIZORAM        25          SPL NARCOTIC       729
# 471             MIZORAM        25            TRAFFIC PS       771
# 472            NAGALAND        26               DIMAPUR       215
# 473            NAGALAND        26               KIPHIRE       426
# 474            NAGALAND        26                KOHIMA       431
# 475            NAGALAND        26              LONGLENG       475
# 476            NAGALAND        26            MOKOKCHUNG       512
# 477            NAGALAND        26                   MON       513
# 478            NAGALAND        26                 PEREN       594
# 479            NAGALAND        26                  PHEK       595
# 480            NAGALAND        26              TUENSANG       778
# 481            NAGALAND        26                 WOKHA       821
# 482            NAGALAND        26             ZUNHEBOTO       825
# 483              ODISHA        27                 ANGUL        34
# 484              ODISHA        27              BALASORE        57
# 485              ODISHA        27              BARAGARH        70
# 486              ODISHA        27             BERHAMPUR        87
# 487              ODISHA        27               BHADRAK        91
# 488              ODISHA        27              BOLANGIR       116
# 489              ODISHA        27                 BOUDH       120
# 490              ODISHA        27               CUTTACK       176
# 491              ODISHA        27              DCP BBSR       192
# 492              ODISHA        27               DCP CTC       193
# 493              ODISHA        27               DEOGARH       196
# 494              ODISHA        27             DHENKANAL       209
# 495              ODISHA        27              GAJAPATI       253
# 496              ODISHA        27                GANJAM       257
# 497              ODISHA        27         JAGATSINGHPUR       327
# 498              ODISHA        27                JAJPUR       340
# 499              ODISHA        27            JHARSUGUDA       364
# 500              ODISHA        27             KALAHANDI       378
# 501              ODISHA        27             KANDHAMAL       383
# 502              ODISHA        27            KENDRAPARA       409
# 503              ODISHA        27              KEONJHAR       410
# 504              ODISHA        27                KHURDA       424
# 505              ODISHA        27               KORAPUT       442
# 506              ODISHA        27             MALKANGIR       493
# 507              ODISHA        27            MAYURBHANJ       503
# 508              ODISHA        27              NAYAGARH       555
# 509              ODISHA        27            NOWRANGPUR       568
# 510              ODISHA        27               NUAPADA       569
# 511              ODISHA        27                  PURI       611
# 512              ODISHA        27              RAYAGADA       643
# 513              ODISHA        27              ROURKELA       651
# 514              ODISHA        27             SAMBALPUR       664
# 515              ODISHA        27               SONEPUR       719
# 516              ODISHA        27          SRP(CUTTACK)       732
# 517              ODISHA        27         SRP(ROURKELA)       733
# 518              ODISHA        27            SUNDARGARH       740
# 519              PUNJAB        29        AMRITSAR RURAL        28
# 520              PUNJAB        29               BARNALA        75
# 521              PUNJAB        29                BATALA        80
# 522              PUNJAB        29              BHATINDA        96
# 523              PUNJAB        29           CP AMRITSAR       166
# 524              PUNJAB        29          CP JALANDHAR       167
# 525              PUNJAB        29           CP LUDHIANA       168
# 526              PUNJAB        29              FARIDKOT       235
# 527              PUNJAB        29       FATEHGARH SAHIB       238
# 528              PUNJAB        29               FAZILKA       240
# 529              PUNJAB        29              FEROZPUR       242
# 530              PUNJAB        29                 G.R.P       244
# 531              PUNJAB        29             GURDASPUR       287
# 532              PUNJAB        29            HOSHIARPUR       309
# 533              PUNJAB        29       JALANDHAR RURAL       342
# 534              PUNJAB        29            KAPURTHALA       392
# 535              PUNJAB        29                KHANNA       414
# 536              PUNJAB        29        LUDHIANA RURAL       478
# 537              PUNJAB        29                 MANSA       500
# 538              PUNJAB        29                  MOGA       511
# 539              PUNJAB        29               MUKTSAR       518
# 540              PUNJAB        29             PATHANKOT       588
# 541              PUNJAB        29               PATIALA       589
# 542              PUNJAB        29                 ROPAR       650
# 543              PUNJAB        29               SANGRUR       667
# 544              PUNJAB        29               SAS NGR       672
# 545              PUNJAB        29             SBS NAGAR       676
# 546              PUNJAB        29            TARN TARAN       748
# 547           RAJASTHAN        30                 AJMER        11
# 548           RAJASTHAN        30                 ALWAR        18
# 549           RAJASTHAN        30              BANSWARA        68
# 550           RAJASTHAN        30                 BARAN        72
# 551           RAJASTHAN        30                BARMER        74
# 552           RAJASTHAN        30             BHARATPUR        94
# 553           RAJASTHAN        30              BHILWARA        98
# 554           RAJASTHAN        30               BIKANER       109
# 555           RAJASTHAN        30                 BUNDI       124
# 556           RAJASTHAN        30           CHITTORGARH       158
# 557           RAJASTHAN        30                 CHURU       160
# 558           RAJASTHAN        30                 DAUSA       190
# 559           RAJASTHAN        30               DHOLPUR       210
# 560           RAJASTHAN        30                DISCOM       218
# 561           RAJASTHAN        30             DUNGARPUR       222
# 621          TAMIL NADU        32    THIRUNELVELI URBAN       756
# 622          TAMIL NADU        32           THIRUVALLUR       757
# 623          TAMIL NADU        32       THIRUVANNAMALAI       758
# 624          TAMIL NADU        32            THIRUVARUR       759
# 625          TAMIL NADU        32           THOOTHUGUDI       760
# 626          TAMIL NADU        32              TIRUPPUR       769
# 627          TAMIL NADU        32           TRICHY RLY.       772
# 628          TAMIL NADU        32          TRICHY RURAL       773
# 629          TAMIL NADU        32          TRICHY URBAN       774
# 630          TAMIL NADU        32               VELLORE       800
# 631          TAMIL NADU        32            VILLUPURAM       805
# 632          TAMIL NADU        32          VIRUDHUNAGAR       807
# 633             TRIPURA        33                DHALAI       200
# 634             TRIPURA        33                GOMATI       273
# 635             TRIPURA        33                   GRP       278
# 636             TRIPURA        33                KHOWAI       422
# 637             TRIPURA        33                 NORTH       562
# 638             TRIPURA        33            SIPAHIJALA       707
# 639             TRIPURA        33                 SOUTH       723
# 640             TRIPURA        33               UNAKOTI       789
# 641             TRIPURA        33                  WEST       819
# 642       UTTAR PRADESH        34                  AGRA         5
# 643       UTTAR PRADESH        34               ALIGARH        14
# 644       UTTAR PRADESH        34             ALLAHABAD        16
# 645       UTTAR PRADESH        34        AMBEDKAR NAGAR        22
# 646       UTTAR PRADESH        34                AMETHI        23
# 647       UTTAR PRADESH        34                AMROHA        29
# 648       UTTAR PRADESH        34               AURAIYA        42
# 649       UTTAR PRADESH        34              AZAMGARH        47
# 650       UTTAR PRADESH        34                BADAUN        48
# 651       UTTAR PRADESH        34               BAGHPAT        53
# 652       UTTAR PRADESH        34              BAHRAICH        54
# 653       UTTAR PRADESH        34                BALLIA        58
# 654       UTTAR PRADESH        34             BALRAMPUR        61
# 655       UTTAR PRADESH        34                 BANDA        62
# 656       UTTAR PRADESH        34             BARABANKI        69
# 657       UTTAR PRADESH        34              BAREILLY        73
# 658       UTTAR PRADESH        34                 BASTI        79
# 659       UTTAR PRADESH        34                BIJNOR       108
# 660       UTTAR PRADESH        34          BULANDSHAHAR       122
# 661       UTTAR PRADESH        34              CHANDOLI       143
# 662       UTTAR PRADESH        34       CHITRAKOOT DHAM       156
# 663       UTTAR PRADESH        34                DEORIA       198
# 664       UTTAR PRADESH        34                  ETAH       231
# 665       UTTAR PRADESH        34                ETAWAH       232
# 666       UTTAR PRADESH        34              FAIZABAD       233
# 667       UTTAR PRADESH        34             FATEHGARH       237
# 668       UTTAR PRADESH        34              FATEHPUR       239
# 669       UTTAR PRADESH        34             FIROZABAD       243
# 670       UTTAR PRADESH        34                G.R.P.       245
# 671       UTTAR PRADESH        34      GAUTAMBUDH NAGAR       265
# 672       UTTAR PRADESH        34             GHAZIABAD       267
# 673       UTTAR PRADESH        34              GHAZIPUR       268
# 674       UTTAR PRADESH        34                 GONDA       274
# 675       UTTAR PRADESH        34             GORAKHPUR       277
# 676       UTTAR PRADESH        34              HAMIRPUR       292
# 677       UTTAR PRADESH        34                 HAPUR       296
# 678       UTTAR PRADESH        34                HARDOI       298
# 679       UTTAR PRADESH        34               HATHRAS       301
# 680       UTTAR PRADESH        34                JALAUN       343
# 681       UTTAR PRADESH        34               JAUNPUR       357
# 682       UTTAR PRADESH        34                JHANSI       362
# 683       UTTAR PRADESH        34               KANNAUJ       386
# 684       UTTAR PRADESH        34          KANPUR DEHAT       388
# 685       UTTAR PRADESH        34          KANPUR NAGAR       389
# 686       UTTAR PRADESH        34               KASGANJ       402
# 687       UTTAR PRADESH        34             KAUSHAMBI       407
# 688       UTTAR PRADESH        34                 KHIRI       421
# 689       UTTAR PRADESH        34           KUSHI NAGAR       459
# 690       UTTAR PRADESH        34              LALITPUR       467
# 691       UTTAR PRADESH        34               LUCKNOW       476
# 692       UTTAR PRADESH        34           MAHARAJGANJ       485
# 693       UTTAR PRADESH        34                MAHOBA       488
# 694       UTTAR PRADESH        34              MAINPURI       489
# 695       UTTAR PRADESH        34               MATHURA       501
# 696       UTTAR PRADESH        34                   MAU       502
# 697       UTTAR PRADESH        34                MEERUT       505
# 698       UTTAR PRADESH        34              MIRZAPUR       510
# 699       UTTAR PRADESH        34             MORADABAD       514
# 700       UTTAR PRADESH        34         MUZAFFARNAGAR       525
# 701       UTTAR PRADESH        34              PILIBHIT       596
# 702       UTTAR PRADESH        34            PRATAPGARH       603
# 703       UTTAR PRADESH        34           RAIBAREILLY       615
# 704       UTTAR PRADESH        34                RAMPUR       638
# 705       UTTAR PRADESH        34            SAHARANPUR       656
# 706       UTTAR PRADESH        34               SAMBHAL       665
# 707       UTTAR PRADESH        34       SANT KABIRNAGAR       668
# 708       UTTAR PRADESH        34          SHAHJAHANPUR       683
# 709       UTTAR PRADESH        34                SHAMLI       685
# 710       UTTAR PRADESH        34             SHRAWASTI       693
# 711       UTTAR PRADESH        34         SIDHARTHNAGAR       698
# 712       UTTAR PRADESH        34               SITAPUR       712
# 713       UTTAR PRADESH        34             SONBHADRA       718
# 714       UTTAR PRADESH        34       ST.RAVIDASNAGAR       734
# 715       UTTAR PRADESH        34             SULTANPUR       739
# 716       UTTAR PRADESH        34                 UNNAO       790
# 717       UTTAR PRADESH        34              VARANASI       799
# 718         UTTARAKHAND        35                ALMORA        17
# 719         UTTARAKHAND        35             BAGESHWAR        52
# 720         UTTARAKHAND        35               CHAMOLI       138
# 721         UTTARAKHAND        35             CHAMPAWAT       139
# 722         UTTARAKHAND        35              DEHRADUN       194
# 723         UTTARAKHAND        35              HARIDWAR       299
# 724         UTTARAKHAND        35              NAINITAL       538
# ...
# 9155             ODISHA        27              NAYAGARH       555
# 9156             ODISHA        27            NOWRANGPUR       568
# 9157             ODISHA        27               NUAPADA       569
# 9158             ODISHA        27                  PURI       611
# 9159             ODISHA        27              RAYAGADA       643
# 9160             ODISHA        27              ROURKELA       651
# 9161             ODISHA        27             SAMBALPUR       664
# 9162             ODISHA        27               SONEPUR       719
# 9163             ODISHA        27          SRP(CUTTACK)       732
# 9164             ODISHA        27         SRP(ROURKELA)       733
# 9165             ODISHA        27            SUNDARGARH       740
# 9228         TAMIL NADU        32               CHENGAI       147
# 9229         TAMIL NADU        32               CHENNAI       148
# 9230         TAMIL NADU        32          CHENNAI RLY.       149
# 9231         TAMIL NADU        32      COIMBATORE RURAL       163
# 9232         TAMIL NADU        32      COIMBATORE URBAN       164
# 9233         TAMIL NADU        32             CUDDALORE       174
# 9234         TAMIL NADU        32            DHARMAPURI       205
# 9235         TAMIL NADU        32              DINDIGUL       216
# 9236         TAMIL NADU        32                 ERODE       230
# 9237         TAMIL NADU        32           KANCHIPURAM       382
# 9238         TAMIL NADU        32           KANYAKUMARI       391
# 9239         TAMIL NADU        32                 KARUR       400
# 9240         TAMIL NADU        32         MADURAI RURAL       482
# 9241         TAMIL NADU        32         MADURAI URBAN       483
# 9242         TAMIL NADU        32          NAGAPATTINAM       533
# 9243         TAMIL NADU        32              NAMAKKAL       542
# 9244         TAMIL NADU        32              NILGIRIS       560
# 9245         TAMIL NADU        32            PERAMBALUR       593
# 9246         TAMIL NADU        32            PUDUKOTTAI       605
# 9247         TAMIL NADU        32         RAMNATHAPURAM       637
# 9248         TAMIL NADU        32           SALEM RURAL       660
# 9249         TAMIL NADU        32           SALEM URBAN       661
# 9250         TAMIL NADU        32            SIVAGANGAI       713
# 9251         TAMIL NADU        32             THANJAVUR       753
# 9252         TAMIL NADU        32                 THENI       754
# 9253         TAMIL NADU        32    THIRUNELVELI RURAL       755
# 9254         TAMIL NADU        32    THIRUNELVELI URBAN       756
# 9255         TAMIL NADU        32           THIRUVALLUR       757
# 9256         TAMIL NADU        32       THIRUVANNAMALAI       758
# 9257         TAMIL NADU        32            THIRUVARUR       759
# 9258         TAMIL NADU        32           THOOTHUGUDI       760
# 9259         TAMIL NADU        32           TRICHY RLY.       772
# 9260         TAMIL NADU        32          TRICHY RURAL       773
# 9261         TAMIL NADU        32          TRICHY URBAN       774
# 9262         TAMIL NADU        32               VELLORE       800
# 9263         TAMIL NADU        32            VILLUPURAM       805
# 9264         TAMIL NADU        32          VIRUDHUNAGAR       807
# 9265            TRIPURA        33                DHALAI       200
# 9266            TRIPURA        33                 NORTH       562
# 9267            TRIPURA        33                 SOUTH       723
# 9268            TRIPURA        33                  WEST       819
# 9269      UTTAR PRADESH        34                  AGRA         5
# 9270      UTTAR PRADESH        34               ALIGARH        14
# 9271      UTTAR PRADESH        34             ALLAHABAD        16
# 9272      UTTAR PRADESH        34        AMBEDKAR NAGAR        22
# 9273      UTTAR PRADESH        34               AURAIYA        42
# 9274      UTTAR PRADESH        34              AZAMGARH        47
# 9275      UTTAR PRADESH        34                BADAUN        48
# 9276      UTTAR PRADESH        34               BAGHPAT        53
# 9277      UTTAR PRADESH        34              BAHRAICH        54
# 9278      UTTAR PRADESH        34                BALLIA        58
# 9279      UTTAR PRADESH        34             BALRAMPUR        61
# 9280      UTTAR PRADESH        34                 BANDA        62
# 9281      UTTAR PRADESH        34             BARABANKI        69
# 9282      UTTAR PRADESH        34              BAREILLY        73
# 9283      UTTAR PRADESH        34                 BASTI        79
# 9284      UTTAR PRADESH        34                BIJNOR       108
# 9285      UTTAR PRADESH        34          BULANDSHAHAR       122
# 9286      UTTAR PRADESH        34              CHANDOLI       143
# 9287      UTTAR PRADESH        34       CHITRAKOOT DHAM       156
# 9288      UTTAR PRADESH        34                DEORIA       198
# 9289      UTTAR PRADESH        34                  ETAH       231
# 9290      UTTAR PRADESH        34                ETAWAH       232
# 9291      UTTAR PRADESH        34              FAIZABAD       233
# 9292      UTTAR PRADESH        34             FATEHGARH       237
# 9293      UTTAR PRADESH        34              FATEHPUR       239
# 9294      UTTAR PRADESH        34             FIROZABAD       243
# 9295      UTTAR PRADESH        34                G.R.P.       245
# 9296      UTTAR PRADESH        34      GAUTAMBUDH NAGAR       265
# 9297      UTTAR PRADESH        34             GHAZIABAD       267
# 9298      UTTAR PRADESH        34              GHAZIPUR       268
# 9299      UTTAR PRADESH        34                 GONDA       274
# 9300      UTTAR PRADESH        34             GORAKHPUR       277
# 9301      UTTAR PRADESH        34              HAMIRPUR       292
# 9302      UTTAR PRADESH        34                HARDOI       298
# 9303      UTTAR PRADESH        34               HATHRAS       301
# 9304      UTTAR PRADESH        34             J.P.NAGAR       324
# 9305      UTTAR PRADESH        34                JALAUN       343
# 9306      UTTAR PRADESH        34               JAUNPUR       357
# 9307      UTTAR PRADESH        34                JHANSI       362
# 9308      UTTAR PRADESH        34               KANNAUJ       386
# 9309      UTTAR PRADESH        34          KANPUR DEHAT       388
# 9310      UTTAR PRADESH        34          KANPUR NAGAR       389
# 9311      UTTAR PRADESH        34             KAUSHAMBI       407
# 9312      UTTAR PRADESH        34                 KHIRI       421
# 9313      UTTAR PRADESH        34           KUSHI NAGAR       459
# 9314      UTTAR PRADESH        34              LALITPUR       467
# 9315      UTTAR PRADESH        34               LUCKNOW       476
# 9316      UTTAR PRADESH        34           MAHARAJGANJ       485
# 9317      UTTAR PRADESH        34                MAHOBA       488
# 9318      UTTAR PRADESH        34              MAINPURI       489
# 9319      UTTAR PRADESH        34               MATHURA       501
# 9320      UTTAR PRADESH        34                   MAU       502
# 9321      UTTAR PRADESH        34                MEERUT       505
# 9322      UTTAR PRADESH        34              MIRZAPUR       510
# 9323      UTTAR PRADESH        34             MORADABAD       514
# 9324      UTTAR PRADESH        34         MUZAFFARNAGAR       525
# 9325      UTTAR PRADESH        34              PILIBHIT       596
# 9326      UTTAR PRADESH        34            PRATAPGARH       603
# 9327      UTTAR PRADESH        34           RAIBAREILLY       615
# 9328      UTTAR PRADESH        34                RAMPUR       638
# 9329      UTTAR PRADESH        34            SAHARANPUR       656
# 9330      UTTAR PRADESH        34       SANT KABIRNAGAR       668
# 9331      UTTAR PRADESH        34          SHAHJAHANPUR       683
# 9332      UTTAR PRADESH        34             SHRAWASTI       693
# 9333      UTTAR PRADESH        34         SIDHARTHNAGAR       698
# 9334      UTTAR PRADESH        34               SITAPUR       712
# 9335      UTTAR PRADESH        34             SONBHADRA       718
# 9336      UTTAR PRADESH        34       ST.RAVIDASNAGAR       734
# 9394           DELHI UT        11                  WEST       819
# 9395        LAKSHADWEEP        20           LAKSHADWEEP       466
# 9396         PUDUCHERRY        28           PONDICHERRY       598

# %%
'''Customizing Predictions for a Specific State
Select a code from the list of states provided and edit it in the code.
The ARIMA model will generate predictions for the chosen state, displaying the forecasted crime trends for the years 2014 to 2023.
This customization allows you to focus on the state of your interest, providing localized insights into crime trends.'''


import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import pandas as pd

# Select the state and prepare the data
state_selected = 34  # Plug in the STATE code from the above list to get the predictions

arima_data = data[data['STATE/UT'] == state_selected].groupby('YEAR')['TOTAL IPC CRIMES'].sum()

# Plot the original data
plt.figure(figsize=(10, 6))
plt.plot(arima_data, label='Total IPC Crimes')
plt.title(f"Total IPC Crimes for State {state_selected}")
plt.xlabel('Year')
plt.ylabel('Total IPC Crimes')
plt.grid(True)
plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller (ADF) test to check for stationarity
adf_test = adfuller(arima_data)
print(f"ADF Statistic: {adf_test[0]}")
print(f"p-value: {adf_test[1]}")

# Check if the data is stationary
if adf_test[1] > 0.05:
    print("Data is non-stationary. Differencing will be applied.")

    # First differencing
    arima_data_diff = arima_data.diff().dropna()  # First differencing

    # Check stationarity again after differencing
    adf_test_diff = adfuller(arima_data_diff)
    print(f"ADF Statistic (Differenced): {adf_test_diff[0]}")
    print(f"p-value (Differenced): {adf_test_diff[1]}")

    if adf_test_diff[1] > 0.05:
        print("Still non-stationary after differencing. Further differencing required.")
        # Second differencing if still non-stationary
        arima_data_diff = arima_data_diff.diff().dropna()
else:
    print("Data is already stationary.")

# Plot the differenced data
plt.figure(figsize=(10, 6))
plt.plot(arima_data_diff, label='Differenced Total IPC Crimes', color='orange')
plt.title(f"Differenced Total IPC Crimes for State {state_selected}")
plt.xlabel('Year')
plt.ylabel('Differenced Total IPC Crimes')
plt.grid(True)
plt.legend()
plt.show()



model = sm.tsa.ARIMA(arima_data_diff, order=(1, 0, 1))  # Adjusted for differenced data
model_fit = model.fit()

# Print the summary of the ARIMA model
print(model_fit.summary())

# Make predictions
start_year = arima_data.index[-1] + 1  # The year after the last data point
arima_pred = model_fit.forecast(steps=10)  # Forecasting for the next 10 years
predicted_years = list(range(start_year, start_year + len(arima_pred)))

# Create a DataFrame to store the predictions
prediction_df = pd.DataFrame({
    'Year': predicted_years,
    'Prediction': arima_pred
})

# Print predictions
print(f"ARIMA Predictions for State {state_selected}:")
print(prediction_df)

# Plotting the predictions
plt.figure(figsize=(10, 6))
plt.plot(prediction_df['Year'], prediction_df['Prediction'], marker='o', color='b', linestyle='-', label='ARIMA Prediction')
plt.title(f"ARIMA Predictions for State {state_selected}")
plt.xlabel('Year')
plt.ylabel('Predicted Total IPC Crimes')
plt.grid(True)
plt.legend()
plt.show()

# Ensure the correct index length when saving to CSV
# The differenced data will have one fewer entry, so adjust for that
corrected_data = pd.DataFrame({
    'Year': arima_data.index[1:],  # Adjust to match the length of differenced data
    'Differenced Total IPC Crimes': arima_data_diff
})

# Save the differenced data and predictions to a CSV file
corrected_data.to_csv('corrected_data.csv', index=False)

# Save predictions to CSV
prediction_df.to_csv('arima_predictions.csv', index=False)
# Out:
# ADF Statistic: -0.46121969756634557
# p-value: 0.8993646419408896
# Data is non-stationary. Differencing will be applied.
# ADF Statistic (Differenced): -4.536706706766679
# p-value (Differenced): 0.0001686939419048436
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       TOTAL IPC CRIMES   No. Observations:                   12
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -137.757
# Date:                Wed, 09 Apr 2025   AIC                            283.514
# Time:                        13:14:49   BIC                            285.453
# Sample:                             0   HQIC                           282.796
#                                  - 12
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4169.9176   9264.304      0.450      0.653    -1.4e+04    2.23e+04
# ar.L1         -0.7949      0.434     -1.830      0.067      -1.646       0.057
# ma.L1          1.0000      0.614      1.629      0.103      -0.203       2.203
# sigma2      5.098e+08   5.52e-09   9.23e+16      0.000     5.1e+08     5.1e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 1.28
# Prob(Q):                              0.81   Prob(JB):                         0.53
# Heteroskedasticity (H):               0.13   Skew:                            -0.79
# Prob(H) (two-sided):                  0.07   Kurtosis:                         2.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
# ARIMA Predictions for State 34:
#     Year   Prediction
# 12  2014  6501.266155
# 13  2015  2316.732260
# 14  2016  5643.011597
# 15  2017  2998.957443
# 16  2018  5100.711884
# 17  2019  3430.030622
# 18  2020  4758.052500
# 19  2021  3702.410022
# 20  2022  4541.538548
# 21  2023  3874.516618

# %%
'''Crime Trend Estimation Using VAR Model
In this section, we implement the VAR (Vector AutoRegression) model for estimating crime trends.
 The VAR model is a powerful statistical tool that captures the interdependencies among multiple time series.
 It allows us to analyze how different types of crimes influence one another over time.

You can run this code directly and then type the name of the state in capital letters with
the correct spelling to generate predictions. This provides a user-friendly way to
explore crime trends for your state of interest, offering deeper insights into the dynamics of crime patterns.'''


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR


file_path = 'crimes_cleaned.csv'  # Path to the cleaned dataset
data = pd.read_csv(file_path)

# Input: Ask the user to select a state for prediction
selected_state = input("Enter the state for which you want to make predictions: ").strip()

# Filter the dataset for the chosen state
state_data = data[data['STATE/UT'] == selected_state]

# Check if data exists for the selected state
if state_data.empty:
    print(f"No data found for the state '{selected_state}'. Please check the input.")
else:
    # Group data by year and aggregate numerical values
    data_aggregated = state_data.groupby('YEAR').sum(numeric_only=True)

    # Define the columns to use for crime trend prediction
    features = [
        'MURDER', 'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER',
        'RAPE', 'CUSTODIAL RAPE', 'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'KIDNAPPING AND ABDUCTION OF OTHERS',
        'DACOITY', 'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY',
        'THEFT', 'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS',
        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'INSULT TO MODESTY OF WOMEN',
        'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES'
    ]
     # Extract training data for the years 2001 to 2013
    train_data = data_aggregated.loc[2001:2013, features]

    # Ensure sufficient training data is available
    if train_data.empty:
        print("Insufficient data for training. Please ensure data from 2001 to 2013 is available.")
    else:
        # Fit a Vector Autoregression (VAR) model
        model = VAR(train_data)
        results = model.fit(maxlags=1)  # Use 1 lag, adjust based on dataset characteristics

        # Generate predictions for the years 2014 to 2023
        forecast = results.forecast(train_data.values, steps=10)
        forecast_df = pd.DataFrame(forecast, index=range(2014, 2024), columns=features)

        # Display the forecasted crime data
        print(f"\nPredicted Crime Data for {selected_state} (2014-2023):")
        print(forecast_df)

        # Combine actual data (up to 2013) with forecasted data (2014 onwards) for visualization
        actual_and_forecast = pd.concat([data_aggregated[features], forecast_df])

        # Visualize the trends using a line plot
        plt.figure(figsize=(15, 10))
        for column in features:
            plt.plot(actual_and_forecast.index, actual_and_forecast[column], label=column)
            # Highlight the prediction period
            plt.axvline(x=2013.5, color='red', linestyle='--', label='Prediction Start' if column == features[0] else None)

        # Add titles, labels, and legend to the plot
        plt.title(f'Crime Predictions for {selected_state} (2014-2023)')
        plt.xlabel('Year')
        plt.ylabel('Crime Counts')
        plt.legend(loc='upper left')
        plt.grid(True)
        # Show the plot
        plt.show()
# Out:
# Enter the state for which you want to make predictions: LAKSHADWEEP
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# Predicted Crime Data for LAKSHADWEEP (2014-2023):
#         MURDER  ATTEMPT TO MURDER  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  \
# 2014  0.080511           0.309578                                        0.0
# 2015  0.119399           0.777278                                        0.0
# 2016  0.728759           0.636584                                        0.0
# 2017 -0.323096           2.051165                                        0.0
# 2018  0.818756          -0.466780                                        0.0
# 2019 -0.513939           1.750266                                        0.0
# 2020  0.713475          -1.369125                                        0.0
# 2021 -0.659465           2.062718                                        0.0
# 2022  0.874415          -1.219250                                        0.0
# 2023 -0.860888           2.569705                                        0.0
#
#           RAPE  CUSTODIAL RAPE  OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 2014  0.487917             0.0    0.487917                0.202480
# 2015  1.279126             0.0    1.279126               -0.240905
# 2016 -0.389395             0.0   -0.389395                0.647066
# 2017  1.101382             0.0    1.101382               -0.505299
# 2018  0.249860             0.0    0.249860                0.986927
# 2019  2.064489             0.0    2.064489               -0.557460
# 2020 -0.676503             0.0   -0.676503                0.848189
# 2021  2.143192             0.0    2.143192               -0.914019
# 2022 -1.980541             0.0   -1.980541                1.080466
# 2023  3.627010             0.0    3.627010               -1.286579
#
#       KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# 2014                                     0.202480
# 2015                                    -0.240905
# 2016                                     0.647066
# 2017                                    -0.505299
# 2018                                     0.986927
# 2019                                    -0.557460
# 2020                                     0.848189
# 2021                                    -0.914019
# 2022                                     1.080466
# 2023                                    -1.286579
#
#       KIDNAPPING AND ABDUCTION OF OTHERS   DACOITY  ...  COUNTERFIETING  \
# 2014                                 0.0  0.962700  ...        0.337681
# 2015                                 0.0  0.415477  ...        0.167883
# 2016                                 0.0 -0.047452  ...        0.085120
# 2017                                 0.0  1.162626  ...       -0.088498
# 2018                                 0.0 -0.883264  ...       -0.042345
# 2019                                 0.0  2.276410  ...       -0.001885
# 2020                                 0.0 -0.618258  ...        0.134008
# 2021                                 0.0  1.581697  ...       -0.006301
# 2022                                 0.0 -1.158576  ...        0.205931
# 2023                                 0.0  1.488723  ...       -0.124129
#
#          ARSON  HURT/GREVIOUS HURT  DOWRY DEATHS  \
# 2014  3.190087            9.822363           0.0
# 2015 -1.819449            2.374982           0.0
# 2016  4.961729            9.069335           0.0
# 2017 -1.167720            1.440960           0.0
# 2018  5.551813            7.831305           0.0
# 2019 -1.461600            6.809587           0.0
# 2020  6.104160            7.593753           0.0
# 2021 -3.072610            1.867579           0.0
# 2022  8.921992            7.856775           0.0
# 2023 -6.896469           -1.822248           0.0
#
#       ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 2014                                           0.192877
# 2015                                           0.910992
# 2016                                          -0.884186
# 2017                                           1.604012
# 2018                                          -0.414433
# 2019                                           1.403680
# 2020                                          -0.759487
# 2021                                           1.400667
# 2022                                          -1.032424
# 2023                                           2.787247
#
#       INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 2014                         0.0                             1.500378
# 2015                         0.0                            -0.084686
# 2016                         0.0                             1.420659
# 2017                         0.0                            -0.011718
# 2018                         0.0                             1.792523
# 2019                         0.0                            -0.815613
# 2020                         0.0                             1.882320
# 2021                         0.0                            -1.855351
# 2022                         0.0                             3.256121
# 2023                         0.0                            -2.511063
#
#       IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# 2014                                          0.0
# 2015                                          0.0
# 2016                                          0.0
# 2017                                          0.0
# 2018                                          0.0
# 2019                                          0.0
# 2020                                          0.0
# 2021                                          0.0
# 2022                                          0.0
# 2023                                          0.0
#
#       CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES
# 2014                          0.0         47.058740
# 2015                          0.0         11.924111
# 2016                          0.0         56.732550
# 2017                          0.0         16.979281
# 2018                          0.0         57.279025
# 2019                          0.0         20.137972
# 2020                          0.0         59.312914
# 2021                          0.0         -5.278667
# 2022                          0.0         74.148955
# 2023                          0.0        -30.085156
#
# [10 rows x 29 columns]

# %%
# Import required libraries
import pandas as pd
from statsmodels.tsa.api import VAR
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller


file_path = 'crimes_cleaned.csv'  # Path to the cleaned dataset
data = pd.read_csv(file_path)

# Display basic information and a preview of the dataset
print("Dataset Information:")
print(data.info())
print("\nFirst 5 Rows of the Dataset:")
print(data.head())

# Aggregate data by year for analysis
yearly_data = data.groupby('YEAR').sum()

#  Select only numeric columns for time series analysis
time_series_data = yearly_data.select_dtypes(include=['int64', 'float64'])

#  Check for stationarity using the Augmented Dickey-Fuller (ADF) Test
def check_stationarity(df):
    """
    Check the stationarity of time series data using the ADF test.
    Returns a DataFrame with ADF statistics and p-values for each column.
    """
    results = {}
    for column in df.columns:
        result = adfuller(df[column])
        results[column] = {'ADF Statistic': result[0], 'p-value': result[1]}
    return pd.DataFrame(results).T
print("\nChecking Stationarity of Time Series Data:")
stationarity_results = check_stationarity(time_series_data)
print(stationarity_results)

#  Apply differencing to handle non-stationary data
# Differencing removes trends to make the data stationary
diff_data = time_series_data.diff().dropna()

#  Fit a Vector Autoregression (VAR) model to the stationary data
model = VAR(diff_data)
fitted_model = model.fit(maxlags=4)  # Fit the model with up to 4 lags (adjustable)

#  7: Forecast crime trends for the next 10 years (2014-2023)
forecast = fitted_model.forecast(diff_data.values[-fitted_model.k_ar:], steps=10)

#  8: Convert forecasted values back to the original scale
# Start by reversing the differencing process
forecast_df = pd.DataFrame(forecast, columns=diff_data.columns)
forecast_cumsum = forecast_df.cumsum()  # Cumulative sum to revert differencing
forecast_original_scale = forecast_cumsum.add(time_series_data.iloc[-1])  # Add last actual value

#  9: Plot actual and forecasted data
plt.figure(figsize=(12, 6))
for column in time_series_data.columns:
    # Plot actual values
    plt.plot(time_series_data.index, time_series_data[column], label=f"Actual {column}")
    # Plot forecasted values
    plt.plot(range(2014, 2024), forecast_original_scale[column], label=f"Forecast {column}")

# Add legend, title, and labels to the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2, fontsize='small')
plt.title("Crime Forecasting with VAR Model")
plt.title("Crime Forecasting with VAR Model")
plt.xlabel("Year")
plt.ylabel("Crime Incidents")
plt.tight_layout()
plt.show()

#  10: Display forecasted values
print("\nForecasted Crime Data for 2014-2023:")
print(forecast_original_scale)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9397 entries, 0 to 9396
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9397 non-null   object
#  1   DISTRICT                                             9397 non-null   object
#  2   YEAR                                                 9397 non-null   int64
#  3   MURDER                                               9397 non-null   int64
#  4   ATTEMPT TO MURDER                                    9397 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9397 non-null   int64
#  6   RAPE                                                 9397 non-null   int64
#  7   CUSTODIAL RAPE                                       9397 non-null   int64
#  8   OTHER RAPE                                           9397 non-null   int64
#  9   KIDNAPPING & ABDUCTION                               9397 non-null   int64
#  10  KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS          9397 non-null   int64
#  11  KIDNAPPING AND ABDUCTION OF OTHERS                   9397 non-null   int64
#  12  DACOITY                                              9397 non-null   int64
#  13  PREPARATION AND ASSEMBLY FOR DACOITY                 9397 non-null   int64
#  14  ROBBERY                                              9397 non-null   int64
#  15  BURGLARY                                             9397 non-null   int64
#  16  THEFT                                                9397 non-null   int64
#  17  AUTO THEFT                                           9397 non-null   int64
#  18  OTHER THEFT                                          9397 non-null   int64
#  19  RIOTS                                                9397 non-null   int64
#  20  CRIMINAL BREACH OF TRUST                             9397 non-null   int64
#  21  CHEATING                                             9397 non-null   int64
#  22  COUNTERFIETING                                       9397 non-null   int64
#  23  ARSON                                                9397 non-null   int64
#  24  HURT/GREVIOUS HURT                                   9397 non-null   int64
#  25  DOWRY DEATHS                                         9397 non-null   int64
#  26  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  9397 non-null   int64
#  27  INSULT TO MODESTY OF WOMEN                           9397 non-null   int64
#  28  CRUELTY BY HUSBAND OR HIS RELATIVES                  9397 non-null   int64
#  29  IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES          9397 non-null   int64
#  30  CAUSING DEATH BY NEGLIGENCE                          9397 non-null   int64
#  31  OTHER IPC CRIMES                                     9397 non-null   int64
#  32  TOTAL IPC CRIMES                                     9397 non-null   int64
# dtypes: int64(31), object(2)
# memory usage: 2.4+ MB
# None
#
# First 5 Rows of the Dataset:
#          STATE/UT   DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH   ADILABAD  2013      96                 72
# 1  ANDHRA PRADESH  ANANTAPUR  2013     156                149
# 2  ANDHRA PRADESH   CHITTOOR  2013      72                 61
# 3  ANDHRA PRADESH   CUDDAPAH  2013      93                107
# 4  ANDHRA PRADESH  CYBERABAD  2013     162                123
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         13    61               0
# 1                                          3    28               0
# 2                                          2    31               0
# 3                                          7    19               0
# 4                                         16   138               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          61                      65  ...     30                2394
# 1          28                     110  ...     29                2537
# 2          31                      52  ...     18                 937
# 3          19                      84  ...     34                2310
# 4         138                     192  ...     40                4284
#
#    DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0            12                                                197
# 1            23                                                337
# 2            13                                                119
# 3             9                                                318
# 4            43                                                350
#
#    INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                         138                                  464
# 1                          43                                  161
# 2                          84                                  435
# 3                         163                                  207
# 4                         338                                 1526
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                          376
# 1                                            0                          573
# 2                                            0                          546
# 3                                            0                          464
# 4                                            0                         1104
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0              1390              6381
# 1              1634              6913
# 2              2239              5610
# 3              1741              7048
# 4              3139             19992
#
# [5 rows x 33 columns]
#
# Checking Stationarity of Time Series Data:
#                                                     ADF Statistic  \
# MURDER                                                  -1.427796
# ATTEMPT TO MURDER                                        0.330358
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               -3.309956
# RAPE                                                     1.877746
# CUSTODIAL RAPE                                          -0.744676
# OTHER RAPE                                               1.878200
# KIDNAPPING & ABDUCTION                                  -4.811820
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRL